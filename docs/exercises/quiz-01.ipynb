# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/yangkc/social-media-analysis/blob/main/docs/exercises/quiz-01.ipynb)

# %% [markdown]
# # Exercise 1: API Basics
#
# This exercise tests your understanding of API concepts and basic data collection.

# %% [markdown]
# ## Problem 1: Authentication
#
# Write code to set up API authentication with proper error handling.
#
# **Requirements:**
# - Handle missing credentials gracefully
# - Provide helpful error messages

# %%
# Your code here

# %% [markdown]
# ## Problem 2: Rate Limiting
#
# Implement a function that respects API rate limits.
#
# **Requirements:**
# - Track number of requests
# - Wait when rate limit is approached
# - Return appropriate status messages

# %%
# Your code here

# %% [markdown]
# ## Problem 3: Data Extraction
#
# Parse JSON response from an API and extract specific fields.
#
# **Requirements:**
# - Handle missing fields
# - Return data in a structured format

# %%
# Your code here
